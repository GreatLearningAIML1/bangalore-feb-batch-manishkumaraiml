# %% [markdown]
# ### Build a DNN using Keras with `RELU` and `ADAM`

# %% [markdown]
# #### Load tensorflow

# %%
import tensorflow as tf

# %% [markdown]
# #### Collect Fashion mnist data from tf.keras.datasets

# %%
from keras.datasets import fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %% [markdown]
# #### Change train and test labels into one-hot vectors

# %%
trainY = tf.keras.utils.to_categorical(y_train)
testY = tf.keras.utils.to_categorical(y_test)

# %% [markdown]
# #### Build the Graph

# %% [markdown]
# #### Initialize model, reshape & normalize data

# %%
x_train=x_train.astype('float32')/255
x_test=x_test.astype('float32')/255

# %%
x_train=x_train.reshape((x_train.shape[0],28,28,1))
x_test=x_test.reshape((x_test.shape[0],28,28,1))

# %%
x_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
from tensorflow.python.keras import Sequential
model = tf.keras.models.Sequential()

# %% [markdown]
# #### Add two fully connected layers with 200 and 100 neurons respectively with `relu` activations. Add a dropout layer with `p=0.25`

# %%
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(200, activation='relu'))
model.add(tf.keras.layers.Dense(100, activation='relu'))
model.add(tf.keras.layers.Dropout(0.25))

# %% [markdown]
# ### Add the output layer with a fully connected layer with 10 neurons with `softmax` activation. Use `categorical_crossentropy` loss and `adam` optimizer and train the network. And, report the final validation.

# %%
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x_train,trainY,          
          validation_data=(x_test,testY),
          epochs=50,
          batch_size=32)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 13s 216us/sample - loss: 0.5226 - acc: 0.8128 - val_loss: 0.4237 - val_acc: 0.8475
# Epoch 2/50
# 60000/60000 [==============================] - 13s 219us/sample - loss: 0.3831 - acc: 0.8595 - val_loss: 0.3879 - val_acc: 0.8596
# Epoch 3/50
# 60000/60000 [==============================] - 14s 226us/sample - loss: 0.3479 - acc: 0.8718 - val_loss: 0.3806 - val_acc: 0.8637
# Epoch 4/50
# 60000/60000 [==============================] - 14s 235us/sample - loss: 0.3221 - acc: 0.8814 - val_loss: 0.3661 - val_acc: 0.8677
# Epoch 5/50
# 60000/60000 [==============================] - 15s 243us/sample - loss: 0.3069 - acc: 0.8865 - val_loss: 0.3456 - val_acc: 0.8790
# Epoch 6/50
# 60000/60000 [==============================] - 15s 251us/sample - loss: 0.2908 - acc: 0.8917 - val_loss: 0.3467 - val_acc: 0.8758
# Epoch 7/50
# 60000/60000 [==============================] - 15s 252us/sample - loss: 0.2778 - acc: 0.8960 - val_loss: 0.3434 - val_acc: 0.8809
# Epoch 8/50
# 60000/60000 [==============================] - 15s 253us/sample - loss: 0.2697 - acc: 0.8984 - val_loss: 0.3484 - val_acc: 0.8764
# Epoch 9/50
# 60000/60000 [==============================] - 15s 253us/sample - loss: 0.2610 - acc: 0.9021 - val_loss: 0.3675 - val_acc: 0.8711
# Epoch 10/50
# 60000/60000 [==============================] - 19s 317us/sample - loss: 0.2527 - acc: 0.9061 - val_loss: 0.3353 - val_acc: 0.8821
# Epoch 11/50
# 60000/60000 [==============================] - 21s 356us/sample - loss: 0.2448 - acc: 0.9081 - val_loss: 0.3456 - val_acc: 0.8856
# Epoch 12/50
# 60000/60000 [==============================] - 23s 383us/sample - loss: 0.2384 - acc: 0.9107 - val_loss: 0.3432 - val_acc: 0.8866
# Epoch 13/50
# 60000/60000 [==============================] - 22s 360us/sample - loss: 0.2314 - acc: 0.9127 - val_loss: 0.3304 - val_acc: 0.8892
# Epoch 14/50
# 60000/60000 [==============================] - 24s 392us/sample - loss: 0.2279 - acc: 0.9133 - val_loss: 0.3370 - val_acc: 0.8817
# Epoch 15/50
# 60000/60000 [==============================] - 21s 342us/sample - loss: 0.2215 - acc: 0.9161 - val_loss: 0.3410 - val_acc: 0.8895
# Epoch 16/50
# 60000/60000 [==============================] - 23s 386us/sample - loss: 0.2174 - acc: 0.9165 - val_loss: 0.3355 - val_acc: 0.8909
# Epoch 17/50
# 60000/60000 [==============================] - 24s 393us/sample - loss: 0.2086 - acc: 0.9189 - val_loss: 0.3420 - val_acc: 0.8894
# Epoch 18/50
# 60000/60000 [==============================] - 20s 326us/sample - loss: 0.2064 - acc: 0.9221 - val_loss: 0.3575 - val_acc: 0.8838
# Epoch 19/50
# 60000/60000 [==============================] - 19s 325us/sample - loss: 0.2031 - acc: 0.9221 - val_loss: 0.3687 - val_acc: 0.8862
# Epoch 20/50
# 60000/60000 [==============================] - 21s 348us/sample - loss: 0.1987 - acc: 0.9240 - val_loss: 0.3610 - val_acc: 0.8919
# Epoch 21/50
# 60000/60000 [==============================] - 23s 376us/sample - loss: 0.1960 - acc: 0.9260 - val_loss: 0.3555 - val_acc: 0.8851
# Epoch 22/50
# 60000/60000 [==============================] - 20s 341us/sample - loss: 0.1902 - acc: 0.9287 - val_loss: 0.3540 - val_acc: 0.8868
# Epoch 23/50
# 60000/60000 [==============================] - 20s 337us/sample - loss: 0.1850 - acc: 0.9277 - val_loss: 0.3956 - val_acc: 0.8882
# Epoch 24/50
# 60000/60000 [==============================] - 24s 398us/sample - loss: 0.1818 - acc: 0.9292 - val_loss: 0.3913 - val_acc: 0.8895
# Epoch 25/50
# 60000/60000 [==============================] - 26s 437us/sample - loss: 0.1777 - acc: 0.9314 - val_loss: 0.3645 - val_acc: 0.8916
# Epoch 26/50
# 60000/60000 [==============================] - 22s 365us/sample - loss: 0.1766 - acc: 0.9325 - val_loss: 0.3661 - val_acc: 0.8926
# Epoch 27/50
# 60000/60000 [==============================] - 22s 367us/sample - loss: 0.1728 - acc: 0.9332 - val_loss: 0.3916 - val_acc: 0.8905
# Epoch 28/50
# 60000/60000 [==============================] - 23s 388us/sample - loss: 0.1711 - acc: 0.9339 - val_loss: 0.3803 - val_acc: 0.8915
# Epoch 29/50
# 60000/60000 [==============================] - 21s 356us/sample - loss: 0.1682 - acc: 0.9346 - val_loss: 0.3897 - val_acc: 0.8904
# Epoch 30/50
# 60000/60000 [==============================] - 21s 357us/sample - loss: 0.1656 - acc: 0.9350 - val_loss: 0.3841 - val_acc: 0.8897
# Epoch 31/50
# 60000/60000 [==============================] - 21s 357us/sample - loss: 0.1655 - acc: 0.9370 - val_loss: 0.3994 - val_acc: 0.8907
# Epoch 32/50
# 60000/60000 [==============================] - 25s 413us/sample - loss: 0.1584 - acc: 0.9388 - val_loss: 0.4004 - val_acc: 0.8892
# Epoch 33/50
# 60000/60000 [==============================] - 27s 449us/sample - loss: 0.1607 - acc: 0.9376 - val_loss: 0.4243 - val_acc: 0.8907
# Epoch 34/50
# 60000/60000 [==============================] - 26s 427us/sample - loss: 0.1548 - acc: 0.9395 - val_loss: 0.4130 - val_acc: 0.8938
# Epoch 35/50
# 60000/60000 [==============================] - 23s 383us/sample - loss: 0.1539 - acc: 0.9400 - val_loss: 0.4218 - val_acc: 0.8879
# Epoch 36/50
# 60000/60000 [==============================] - 21s 357us/sample - loss: 0.1530 - acc: 0.9411 - val_loss: 0.4463 - val_acc: 0.8917
# Epoch 37/50
# 60000/60000 [==============================] - 23s 381us/sample - loss: 0.1523 - acc: 0.9411 - val_loss: 0.4255 - val_acc: 0.8902
# Epoch 38/50
# 60000/60000 [==============================] - 30s 506us/sample - loss: 0.1490 - acc: 0.9419 - val_loss: 0.4324 - val_acc: 0.8941
# Epoch 39/50
# 60000/60000 [==============================] - 30s 494us/sample - loss: 0.1482 - acc: 0.9419 - val_loss: 0.4362 - val_acc: 0.8904
# Epoch 40/50
# 60000/60000 [==============================] - 24s 405us/sample - loss: 0.1427 - acc: 0.9434 - val_loss: 0.4533 - val_acc: 0.8933
# Epoch 41/50
# 60000/60000 [==============================] - 24s 405us/sample - loss: 0.1446 - acc: 0.9437 - val_loss: 0.4823 - val_acc: 0.8847
# Epoch 42/50
# 60000/60000 [==============================] - 26s 432us/sample - loss: 0.1433 - acc: 0.9451 - val_loss: 0.4793 - val_acc: 0.8846
# Epoch 43/50
# 60000/60000 [==============================] - 24s 394us/sample - loss: 0.1399 - acc: 0.9458 - val_loss: 0.4198 - val_acc: 0.8913
# Epoch 44/50
# 60000/60000 [==============================] - 21s 357us/sample - loss: 0.1359 - acc: 0.9468 - val_loss: 0.4410 - val_acc: 0.8919
# Epoch 45/50
# 60000/60000 [==============================] - 21s 348us/sample - loss: 0.1367 - acc: 0.9471 - val_loss: 0.4541 - val_acc: 0.8869
# Epoch 46/50
# 60000/60000 [==============================] - 22s 368us/sample - loss: 0.1343 - acc: 0.9481 - val_loss: 0.4438 - val_acc: 0.8921
# Epoch 47/50
# 60000/60000 [==============================] - 22s 364us/sample - loss: 0.1343 - acc: 0.9475 - val_loss: 0.4544 - val_acc: 0.8878
# Epoch 48/50
# 60000/60000 [==============================] - 21s 345us/sample - loss: 0.1340 - acc: 0.9478 - val_loss: 0.4676 - val_acc: 0.8939
# Epoch 49/50
# 60000/60000 [==============================] - 23s 390us/sample - loss: 0.1286 - acc: 0.9491 - val_loss: 0.4971 - val_acc: 0.8918
# Epoch 50/50
# 60000/60000 [==============================] - 28s 463us/sample - loss: 0.1332 - acc: 0.9481 - val_loss: 0.5020 - val_acc: 0.8874

# %%
print("train score: ", model.evaluate(x_train,trainY))
# Out:
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.1120 - acc: 0.9568
# train score:  [0.11198409690658251, 0.9568]

# %%
print("test score: ", model.evaluate(x_test,testY))
# Out:
# 10000/10000 [==============================] - 0s 49us/sample - loss: 0.5020 - acc: 0.8874
# test score:  [0.5019779056072236, 0.8874]

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_7 (Flatten)          multiple                  0
# _________________________________________________________________
# dense_41 (Dense)             multiple                  157000
# _________________________________________________________________
# dense_42 (Dense)             multiple                  20100
# _________________________________________________________________
# dropout_14 (Dropout)         multiple                  0
# _________________________________________________________________
# dense_43 (Dense)             multiple                  1010
# =================================================================
# Total params: 178,110
# Trainable params: 178,110
# Non-trainable params: 0
# _________________________________________________________________
